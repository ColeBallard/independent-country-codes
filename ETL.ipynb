# %%
import pandas as pd

# %%
le = pd.read_csv('Life_Expectancy.csv', skiprows = 3)

# %%
ccodes = pd.read_csv('country-codes.csv')

# %%
le.drop(['Indicator Code', '2021', 'Indicator Name', 'Country Code', 'Unnamed: 66'], axis = 1, inplace = True)

# %%
pd.set_option('display.max_columns', 500)

# %%
pd.set_option('display.max_rows', 500)

# %%
le.dropna(thresh = 2, inplace = True)

# %%
le_T = le.set_index('Country Name').T

# %%
countrieslist = list(ccodes['English short name (using title case)'])

# %%
for i in le_T.columns:
    if i not in countrieslist:
        le_T.drop([i], axis = 1, inplace = True)

# %%
le.T[[9]][1:].plot()
# Out:
# <AxesSubplot:>

# %%
le.nlargest(5,'2020')
# Out:
#              Country Name       1960       1961       1962       1963  \
# 96   Hong Kong SAR, China  66.961683  67.548756  68.105976  68.625854
# 119                 Japan  67.666098  68.310000  68.594878  69.658049
# 146      Macao SAR, China  64.828000  65.301000  65.757000  66.199000
# 208             Singapore  65.659829  66.087195  66.432244  66.700805
# 126           Korea, Rep.  55.415537  56.014976  56.512317  56.970610
#
#           1964       1965       1966       1967       1968       1969  \
# 96   69.104366  69.542878  69.946220  70.325780  70.690537  71.044561
# 119  70.132439  70.201951  70.986585  71.276585  71.611220  71.838780
# 146  66.629000  67.055000  67.486000  67.928000  68.388000  68.865000
# 208  66.910220  67.085805  67.255951  67.445732  67.673732  67.951073
# 126  57.440927  57.968293  58.575171  59.241463  59.944610  60.675024
#
#           1970       1971       1972       1973       1974       1975  \
# ...

# %%
le.nsmallest(5,'2020')
# Out:
#                  Country Name    1960    1961    1962    1963    1964    1965  \
# 34   Central African Republic  36.249  36.715  37.190  37.683  38.201  38.754
# 229                      Chad  38.020  38.279  38.536  38.795  39.059  39.344
# 141                   Lesotho  47.919  48.162  48.383  48.590  48.797  49.015
# 174                   Nigeria  36.976  37.431  37.871  38.291  38.691  39.072
# 210              Sierra Leone  31.566  31.925  32.302  32.705  33.134  33.590
#
#        1966    1967    1968    1969    1970    1971    1972    1973    1974  \
# 34   39.355  40.005  40.703  41.444  42.223  43.036  43.866  44.695  45.504
# 229  39.665  40.028  40.435  40.878  41.344  41.813  42.264  42.681  43.059
# 141  49.254  49.523  49.829  50.180  50.584  51.048  51.565  52.129  52.731
# 174  39.442  39.809  40.184  40.569  40.971  41.392  41.829  42.276  42.729
# 210  34.072  34.572  35.080  35.590  36.098  36.599  37.092  37.572  38.032
#
# ...
